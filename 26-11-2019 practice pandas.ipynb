# %% [markdown]
# ### Global Sales Data
# - Observe the five CSV Files in the Global Sales Data Folder
# - Read the market_fact.csv data

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/sumathi16/MSTP-MTP-L3/master/Datasets/global_sales_data/market_fact.csv")
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %% [markdown]
# ### check shape

# %%
df.shape
# Out:
# (8399, 10)

# %% [markdown]
# ### observe the top 4 rows

# %%
# Observe the top 4 rows
df.head(4)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37

# %% [markdown]
# ###  Observe the last 2 rows

# %%
df.tail(2)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.87      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %% [markdown]
# ### Observe 5 rows randomly

# %%
df.sample(5)
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8068  Ord_5362  Prod_5  SHP_7490  Cust_1805  1079.19      0.07
# 600   Ord_4841  Prod_6  SHP_6752  Cust_1675   208.47      0.01
# 4324  Ord_2234  Prod_1  SHP_3035   Cust_863  5934.39      0.08
# 5952  Ord_1787  Prod_3  SHP_2474   Cust_589  2378.82      0.02
# 7265  Ord_3455  Prod_8  SHP_4790  Cust_1179   220.07      0.01
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8068              12   46.80          39.61                 0.67
# 600               29 -125.60           8.74                 0.36
# 4324              32  519.55          19.99                 0.71
# 5952              43  597.16          16.11                 0.39
# 7265              44 -158.42           4.93                 0.66

# %% [markdown]
# ### Check the column names

# %%
df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %% [markdown]
# ### Check the row indices

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %% [markdown]
# ###  Check for the missing values if there are any print the count
# ### column wise

# %%
df.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
df.isnull().sum().sum()#totall missing columns
# Out:
# 63

# %%
df.dtypes
# Out:
# Ord_id                  object
# Prod_id                 object
# Ship_id                 object
# Cust_id                 object
# Sales                  float64
# Discount               float64
# Order_Quantity           int64
# Profit                 float64
# Shipping_Cost          float64
# Product_Base_Margin    float64
# dtype: object

# %%
# Calculate the no of columns for each type
df.dtypes.value_counts()
# Out:
# float64    5
# object     4
# int64      1
# dtype: int64

# %%
# What are the min and max values in ecah column
df.describe().loc[['min','max']]
# Out:
#         Sales  Discount  Order_Quantity    Profit  Shipping_Cost  \
# min      2.24      0.00             1.0 -14140.70           0.49
# max  89061.05      0.25            50.0  27220.69         164.73
#
#      Product_Base_Margin
# min                 0.35
# max                 0.85

# %%
# Calculate count,mean,std,max,25%,50%,75% quartile
df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
#categorical column
cat_cols=df.columns[df.dtypes==object]
cat_cols
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id'], dtype='object')

# %%
# Calculate the no of unique values in each categorical column
df.nunique()
# Out:
# Ord_id                 5506
# Prod_id                  17
# Ship_id                7701
# Cust_id                1832
# Sales                  8153
# Discount                 16
# Order_Quantity           50
# Profit                 7807
# Shipping_Cost           652
# Product_Base_Margin      51
# dtype: int64

# %%
df.describe(include=object)
# Out:
#          Ord_id Prod_id   Ship_id    Cust_id
# count      8399    8399      8399       8399
# unique     5506      17      7701       1832
# top     Ord_542  Prod_6  SHP_5602  Cust_1140
# freq          6    1225         4         30

# %%
# Calculate category frequecies for each value in the categorical 
# column
for i in cat_cols:
    print(df[i].value_counts())
# Out:
# Ord_542     6
# Ord_2506    6
# Ord_2894    5
# Ord_2370    5
# Ord_56      5
# Ord_1639    5
# Ord_1581    5
# Ord_4946    5
# Ord_4025    5
# Ord_1931    5
# Ord_1664    5
# Ord_996     5
# Ord_2164    5
# Ord_1791    5
# Ord_1053    5
# Ord_2970    5
# Ord_1234    5
# Ord_5186    5
# Ord_1846    5
# Ord_845     5
# Ord_1980    5
# Ord_589     4
# Ord_2915    4
# Ord_3627    4
# Ord_920     4
# Ord_4014    4
# Ord_841     4
# Ord_1705    4
# Ord_1793    4
# Ord_1851    4
#            ..
# Ord_2305    1
# Ord_5489    1
# Ord_673     1
# Ord_3475    1
# Ord_4239    1
# Ord_226     1
# Ord_258     1
# Ord_4857    1
# Ord_371     1
# Ord_2260    1
# Ord_21      1
# Ord_5454    1
# Ord_4385    1
# Ord_4320    1
# Ord_2036    1
# Ord_3513    1
# Ord_2470    1
# Ord_3056    1
# Ord_74      1
# Ord_3210    1
# Ord_4112    1
# Ord_3415    1
# Ord_4794    1
# Ord_2267    1
# Ord_803     1
# Ord_5007    1
# Ord_1391    1
# Ord_3985    1
# Ord_5010    1
# Ord_4180    1
# ...

# %% [markdown]
# ### Read the remaing four csv files.Store them in cust_df,prod_df,ship_df,order_df

# %%
folder_path=('https://raw.githubusercontent.com/sumathi16/MSTP-MTP-L3/master/Datasets/global_sales_data/')
cust_df =pd.read_csv(folder_path+'cust_dimen.csv')
prod_df =pd.read_csv(folder_path+'prod_dimen.csv')
ship_df =pd.read_csv(folder_path+'shipping_dimen.csv')
order_df=pd.read_csv(folder_path+'orders_dimen.csv')
print(cust_df)
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1           BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER     Cust_2
# 2          CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE     Cust_3
# 3         CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER     Cust_4
# 4           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# 5         MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE     Cust_6
# 6        DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_7
# 7        NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_8
# 8            CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_9
# 9          CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_10
# 10      ALLEN ROSENBLATT  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_11
# 11       SYLVIA FOULSTON  NUNAVUT  NUNAVUT      HOME OFFICE    Cust_12
# ...

# %%
ship_df.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
order_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
# Merge the market_fact and cust_df files and store the result 
# in df1
df1=pd.merge(df,cust_df,on='Cust_id')
df1.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Customer_Name', 'Province', 'Region', 'Customer_Segment'],
#       dtype='object')

# %%
print(df1.shape)
# Out:
# (8399, 14)

# %%
# Merge the df1 and prod_df files and store the result  in df2
df2=pd.merge(df1,prod_df,on='Prod_id')
df2.shape
# Out:
# (8399, 16)

# %%
# Merge the df2 and ship_df files and store the result  in df3
df3=pd.merge(df2,ship_df,on='Ship_id')
df3.shape
# Out:
# (8399, 19)

# %%
# Merge the df3 and order_df files and store the result  in 
df=pd.merge(df3,order_df,on='Ord_id')
df.shape
# Out:
# (8399, 22)

# %%
df.Product_Category.value_counts()
# Out:
# OFFICE SUPPLIES    4610
# TECHNOLOGY         2065
# FURNITURE          1724
# Name: Product_Category, dtype: int64

# %%
df.groupby('Product_Category').Sales.max()
# Out:
# Product_Category
# FURNITURE          29345.27
# OFFICE SUPPLIES    25409.63
# TECHNOLOGY         89061.05
# Name: Sales, dtype: float64

# %%
df.groupby('Product_Category').Sales.max().max()
# Out:
# 89061.05

# %%
df.groupby(['Customer_Segment','Product_Category']).Sales.max()
# Out:
# Customer_Segment  Product_Category
# CONSUMER          FURNITURE           28389.14
#                   OFFICE SUPPLIES     23516.31
#                   TECHNOLOGY          89061.05
# CORPORATE         FURNITURE           29345.27
#                   OFFICE SUPPLIES     23106.46
#                   TECHNOLOGY          41343.21
# HOME OFFICE       FURNITURE           28180.08
#                   OFFICE SUPPLIES     18697.24
#                   TECHNOLOGY          45923.76
# SMALL BUSINESS    FURNITURE           24639.80
#                   OFFICE SUPPLIES     25409.63
#                   TECHNOLOGY          33367.85
# Name: Sales, dtype: float64

# %% [markdown]
# ### Observe Histograms for numerical columns
# ### Bar plots for categorical columns
# ### Scatter plots between numerical columns

# %%
df.corr()
# Out:
#                         Sales  Discount  Order_Quantity    Profit  \
# Sales                1.000000 -0.019686        0.220582  0.581960
# Discount            -0.019686  1.000000       -0.009649 -0.037128
# Order_Quantity       0.220582 -0.009649        1.000000  0.194655
# Profit               0.581960 -0.037128        0.194655  1.000000
# Shipping_Cost        0.434578 -0.001956       -0.011457 -0.021362
# Product_Base_Margin  0.156759  0.004079        0.007839 -0.112985
# Order_ID_x          -0.007792 -0.003213        0.010953 -0.006820
# Order_ID_y          -0.007792 -0.003213        0.010953 -0.006820
#
#                      Shipping_Cost  Product_Base_Margin  Order_ID_x  \
# Sales                     0.434578             0.156759   -0.007792
# Discount                 -0.001956             0.004079   -0.003213
# Order_Quantity           -0.011457             0.007839    0.010953
# Profit                   -0.021362            -0.112985   -0.006820
# ...

# %%
#categorical column
cat_cols=df.columns[df.dtypes==object]
cat_cols
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Customer_Name', 'Province',
#        'Region', 'Customer_Segment', 'Product_Category',
#        'Product_Sub_Category', 'Ship_Mode', 'Ship_Date', 'Order_Date',
#        'Order_Priority'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=list(pd.Series(df['Sales']))

# %%
plt.hist(a)
# Out:
# (array([8.047e+03, 2.580e+02, 7.800e+01, 1.300e+01, 1.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.2400000e+00, 8.9081210e+03, 1.7814002e+04, 2.6719883e+04,
#         3.5625764e+04, 4.4531645e+04, 5.3437526e+04, 6.2343407e+04,
#         7.1249288e+04, 8.0155169e+04, 8.9061050e+04]),
#  <a list of 10 Patch objects>)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 0 to 8398
# Data columns (total 22 columns):
# Ord_id                  8399 non-null object
# Prod_id                 8399 non-null object
# Ship_id                 8399 non-null object
# Cust_id                 8399 non-null object
# Sales                   8399 non-null float64
# Discount                8399 non-null float64
# Order_Quantity          8399 non-null int64
# Profit                  8399 non-null float64
# Shipping_Cost           8399 non-null float64
# Product_Base_Margin     8336 non-null float64
# Customer_Name           8399 non-null object
# Province                8399 non-null object
# Region                  8399 non-null object
# Customer_Segment        8399 non-null object
# Product_Category        8399 non-null object
# Product_Sub_Category    8399 non-null object
# Order_ID_x              8399 non-null int64
# Ship_Mode               8399 non-null object
# ...

# %%
num_cols=df.columns[df.dtypes!=object]
num_cols
# Out:
# Index(['Sales', 'Discount', 'Order_Quantity', 'Profit', 'Shipping_Cost',
#        'Product_Base_Margin', 'Order_ID_x', 'Order_ID_y'],
#       dtype='object')

# %%
df['Product_Base_Margin'].isnull().sum()
# Out:
# 63

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.0.3'

# %%
for i in range(len(num_cols)):
    plt.subplot(3,3,i+1)
    plt.hist(df[num_cols[i]])

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002897DEBF5F8>,
# ...
#       dtype=object)

# %%
sns.countplot(df['Prod_id'])

# %%
plt.boxplot([1,10,20,200,50])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2897fa57048>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2897fa57710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2897fa4deb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2897fa57da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2897fa61128>],
#  'means': []}

# %%
q1=np.quantile([1,10,20,200,50],0.25)#median of 1st half
q2=np.quantile([1,10,20,200,50],0.5)#median
q3=np.quantile([1,10,20,200,50],0.75)#second half median

# %%
q1,q2,q3
# Out:
# (10.0, 20.0, 50.0)

# %%
IQR=1.5*(q3-q1)# inter quqntile range
print(q1-IQR,q3+IQR)
# Out:
# -50.0 110.0

# %%
plt.boxplot(df['Order_Quantity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2897de2c588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2897deba278>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2897de2c7f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2897deba0b8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2897deba208>],
#  'means': []}

# %%
sns.boxplot(df['Order_Quantity'])

# %%
sns.boxplot(y=df['Order_Quantity'])

# %%
plt.scatter(df['Sales'],df['Discount'])

# %%
sns.pairplot(df)

# %%
b=list(pd.Series(df['Discount']))
plt.hist(b)
# Out:
# (array([2.327e+03, 1.549e+03, 2.230e+03, 1.543e+03, 7.460e+02, 0.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 1.000e+00]),
#  array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#         0.225, 0.25 ]),
#  <a list of 10 Patch objects>)

# %%
c=list(pd.Series(df['Order_Quantity']))
plt.hist(c)
# Out:
# (array([868., 847., 789., 816., 854., 827., 848., 825., 876., 849.]),
#  array([ 1. ,  5.9, 10.8, 15.7, 20.6, 25.5, 30.4, 35.3, 40.2, 45.1, 50. ]),
#  <a list of 10 Patch objects>)

# %%
d=list(pd.Series(df['Profit']))
plt.hist(d)
# Out:
# (array([7.000e+00, 9.000e+00, 7.300e+01, 8.066e+03, 1.880e+02, 4.600e+01,
#         9.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-14140.7  , -10004.561,  -5868.422,  -1732.283,   2403.856,
#           6539.995,  10676.134,  14812.273,  18948.412,  23084.551,
#          27220.69 ]),
#  <a list of 10 Patch objects>)

# %%
e=list(pd.Series(df['Shipping_Cost']))
plt.hist(e)
# Out:
# (array([6.583e+03, 8.600e+02, 4.180e+02, 3.260e+02, 1.530e+02, 4.200e+01,
#         1.000e+01, 2.000e+00, 3.000e+00, 2.000e+00]),
#  array([  0.49 ,  16.914,  33.338,  49.762,  66.186,  82.61 ,  99.034,
#         115.458, 131.882, 148.306, 164.73 ]),
#  <a list of 10 Patch objects>)

# %%
df.corr()
# Out:
#                         Sales  Discount  Order_Quantity    Profit  \
# Sales                1.000000 -0.019686        0.220582  0.581960
# Discount            -0.019686  1.000000       -0.009649 -0.037128
# Order_Quantity       0.220582 -0.009649        1.000000  0.194655
# Profit               0.581960 -0.037128        0.194655  1.000000
# Shipping_Cost        0.434578 -0.001956       -0.011457 -0.021362
# Product_Base_Margin  0.156759  0.004079        0.007839 -0.112985
# Order_ID_x          -0.007792 -0.003213        0.010953 -0.006820
# Order_ID_y          -0.007792 -0.003213        0.010953 -0.006820
#
#                      Shipping_Cost  Product_Base_Margin  Order_ID_x  \
# Sales                     0.434578             0.156759   -0.007792
# Discount                 -0.001956             0.004079   -0.003213
# Order_Quantity           -0.011457             0.007839    0.010953
# Profit                   -0.021362            -0.112985   -0.006820
# ...

# %% [markdown]
# ### check what is box plot and observe the outliers in each numerical column using boxplot

# %% [markdown]
# ### for boxplot calculations
# - https://www.mathsisfun.com/data/quartiles.html

# %% [markdown]
# ### Dataseta--Google Datasets,Kaggle,UCI Datasets
